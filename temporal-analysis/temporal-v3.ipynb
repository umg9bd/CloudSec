# %%
import pandas as pd

# %%
df = pd.read_csv("invictus_enriched.csv")
print(df.head())
print(df.info())
print(df.shape)
# Out:
#                    timestamp          event_name           event_source  \
# 0  2023-07-10 11:42:18+00:00  GetRegionOptStatus  account.amazonaws.com
# 1  2023-07-10 11:42:23+00:00    GetBucketLogging       s3.amazonaws.com
# 2  2023-07-10 11:42:23+00:00     GetBucketPolicy       s3.amazonaws.com
# 3  2023-07-10 11:42:24+00:00        GetBucketAcl       s3.amazonaws.com
# 4  2023-07-10 11:42:24+00:00   GetBucketLocation       s3.amazonaws.com
#
#   aws_region     source_ip error_code  label attack_technique  read_only  \
# 0  us-east-1  10.248.16.43        NaN      0              NaN       True
# 1  us-east-1  10.248.16.43        NaN      0              NaN       True
# 2  us-east-1  10.248.16.43        NaN      0              NaN       True
# 3  us-east-1  10.248.16.43        NaN      0              NaN       True
# 4  us-east-1  10.248.16.43        NaN      0              NaN       True
#
#                                           user_agent         access_key_id  \
# ...

# %% [markdown]
# timestamp parsed

# %%
print(df['timestamp'].dtype)   
print(df['timestamp'].min(), df['timestamp'].max())
# Out:
# object
# 2023-07-10 11:42:18+00:00 2023-07-10 12:37:50+00:00

# %%
print(df.duplicated().sum())
print(df.duplicated(subset=['username','timestamp','event_name']).sum())
# Out:
# 242
# 1347

# %%
print(df['username'].isna().sum())         
print(df['username'].nunique())            
print(df['username'].value_counts())
# Out:
# 42
# 18
# username
# bert-jan                                       2642
# benjamin                                        105
# stratus-red-team-ec2-get-password-data-role      29
# stratus-red-team-ec2-steal-credentials-role      15
# stratus-red-team-get-usr-data-role               15
# rds.amazonaws.com                                10
# stratus-red-team-ec2-enumerate-role               8
# cloudtrail.amazonaws.com                          8
# rolesanywhere.amazonaws.com                       6
# ec2.amazonaws.com                                 4
# inspector2.amazonaws.com                          4
# AWSServiceRoleForRDS                              4
# lambda.amazonaws.com                              2
# AWSServiceRoleForAmazonInspector2                 2
# stratus-red-team-leave-org-role                   1
# stratus-red-team-ec2lui-role-pcccexdthk           1
# stratus-red-team-ec2lui-role-wuzemnoeqa           1
# stratus-red-team-nmfalu-gfjyeaypjt                1
# ...
